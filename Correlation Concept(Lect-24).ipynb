# %% [markdown]
# # Correlataion

# %%
import numpy as np
import pandas as pd

# seed for reproducibility

np.random.seed(42)

# generate sample data

data={
    'Age':np.random.normal(30,10,100).astype(int),
    'Weight':np.random.normal(50,10,100).astype(int),
    'Height':np.random.normal(60,10,100).astype(int)
}
# create Dataframe

df=pd.DataFrame(data)
df
# Out:
#     Age  Weight  Height
# 0    34      35      63
# 1    28      45      65
# 2    36      46      70
# 3    45      41      70
# 4    27      48      46
# ..  ...     ...     ...
# 95   15      53      53
# 96   32      41      68
# 97   32      51      63
# 98   30      50      68
# 99   27      38      66
#
# [100 rows x 3 columns]

# %%
# !pip install tabulate

# %%
from tabulate import tabulate

# %%
correlations=df.corr()
correlations
# Out:
#              Age    Weight    Height
# Age     1.000000 -0.134354  0.192761
# Weight -0.134354  1.000000 -0.031665
# Height  0.192761 -0.031665  1.000000

# %%
# print the correlation matrix as a table
print(tabulate(correlations, headers='keys', tablefmt='grid',numalign='right',floatfmt='.2f'))
# Out:
# +--------+-------+----------+----------+
# |        |   Age |   Weight |   Height |
# +========+=======+==========+==========+
# | Age    |  1.00 |    -0.13 |     0.19 |
# +--------+-------+----------+----------+
# | Weight | -0.13 |     1.00 |    -0.03 |
# +--------+-------+----------+----------+
# | Height |  0.19 |    -0.03 |     1.00 |
# +--------+-------+----------+----------+
